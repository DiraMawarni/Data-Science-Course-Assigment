# %% [markdown]
# <a href="https://colab.research.google.com/github/DiraMawarni/Data-Science-Course-Assigment/blob/main/Latihan_2_1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Latihan (1)**

# %%
# Install modul kaggle secara inline (di dalam notebook)
# !pip install kaggle

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  
# Then move kaggle.json into the folder where the API expects to find it.
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-2a8408e7-c04e-407e-b65b-cf299e26493d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a8408e7-c04e-407e-b65b-cf299e26493d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# User uploaded file "kaggle.json" with length 67 bytes

# %%
# Mencari dataset yang tersedia di kaggle --> pilih data provider dari UCIML
# !kaggle datasets list -s Students-Adaptability-Level-in-Online-Education
# Out:
# ref                                                                            title                                            size  lastUpdated          downloadCount  voteCount  usabilityRating
# -----------------------------------------------------------------------------  -----------------------------------------------  ----  -------------------  -------------  ---------  ---------------
# datasets/mdmahmudulhasansuzan/students-adaptability-level-in-online-education  Students Adaptability Level in Online Education   6KB  2022-04-16 04:46:28            877         37  1.0

# %%
# Download dan ekstrak dataset, secara default akan berada dalam satu direktori dengan notebook ini
# !kaggle datasets download mdmahmudulhasansuzan/students-adaptability-level-in-online-education --unzip
# Out:
# ...
#   0% 0.00/6.43k [00:00<?, ?B/s]
# 100% 6.43k/6.43k [00:00<00:00, 2.99MB/s]

# %% [markdown]
# # **Latihan (2)**

# %% [markdown]
# Lakukan import Library Pandas dan Library Numpy

# %%
#Latihan(2)
#Import Library Pandas

import pandas as pd

#Import Library Numpy

import numpy as np

# %% [markdown]
# # **Latihan (3)**

# %%
#latihan(3)
#Panggil file (load file bernama students-adaptability-level-in-online-education.csv) dan simpan dalam dataframe Lalu tampilkan 5 baris awal dataset dengan function head()

df = pd.read_csv("/content/students_adaptability_level_online_education.csv")
df.head(5)
# Out:
#   Gender    Age Education Level Institution Type IT Student Location  \
# 0    Boy  21-25      University   Non Government         No      Yes
# 1   Girl  21-25      University   Non Government         No      Yes
# 2   Girl  16-20         College       Government         No      Yes
# 3   Girl  11-15          School   Non Government         No      Yes
# 4   Girl  16-20          School   Non Government         No      Yes
#
#   Load-shedding Financial Condition Internet Type Network Type Class Duration  \
# 0           Low                 Mid          Wifi           4G            3-6
# 1          High                 Mid   Mobile Data           4G            1-3
# 2           Low                 Mid          Wifi           4G            1-3
# 3           Low                 Mid   Mobile Data           4G            1-3
# 4           Low                Poor   Mobile Data           3G              0
#
#   Self Lms  Device Adaptivity Level
# 0       No     Tab         Moderate
# ...

# %% [markdown]
# # **Latihan (4)**

# %%
#latihan(4)
#Tampilkan tipe data dari kolom yang ada pada dataset
df.dtypes
# Out:
# Gender                 object
# Age                    object
# Education Level        object
# Institution Type       object
# IT Student             object
# Location               object
# Load-shedding          object
# Financial Condition    object
# Internet Type          object
# Network Type           object
# Class Duration         object
# Self Lms               object
# Device                 object
# Adaptivity Level       object
# dtype: object

# %% [markdown]
# # **Latihan (5)**

# %%
#Latihan (5)
#Tipe Data dari kolom yang ada di dataset

#Kolom "Gender" memiliki tipe data =                  object
#Kolom "Age" memiliki tipe data =                     object
#Kolom "Education Level" memiliki tipe data =         object
#Kolom "Institution Type" memiliki tipe data =        object
#Kolom "IT Student" memiliki tipe data =              object
#Kolom "Location" memiliki tipe data =                object
#Kolom "Load-shedding" memiliki tipe data =           object
#Kolom "Financial Condition" memiliki tipe data =     object
#Kolom "Internet Type" memiliki tipe data =           object
#Kolom "Network Type" memiliki tipe data =            object
#Kolom "Class Duration" memiliki tipe data =          object
#Kolom "Self Lms" memiliki tipe data =                object
#Kolom "Device" memiliki tipe data =                  object
#Kolom "Adaptivity Level" memiliki tipe data =        object

# %% [markdown]
# # **Latihan (6)**

# %%
#Latihan (6)
#Hitung ukuran (jumlah baris dan kolom) dari dataset

df.shape
# Out:
# (1205, 14)

# %% [markdown]
# # **Latihan (7)**

# %%
#Latihan (7)

#Jumlah Baris pada dataset adalah =  1205

#Jumlah kolom pada dataset adalah =  14

# %% [markdown]
# # **Latihan (8)**

# %%
#Latihan (8)
#Tampilkan data untuk kolom "age" dan kolom "gender" dalam bentuk dataframe

df[["Age","Gender"]]
# Out:
#         Age Gender
# 0     21-25    Boy
# 1     21-25   Girl
# 2     16-20   Girl
# 3     11-15   Girl
# 4     16-20   Girl
# ...     ...    ...
# 1200  16-20   Girl
# 1201  16-20   Girl
# 1202  11-15    Boy
# 1203  16-20   Girl
# 1204  11-15   Girl
#
# [1205 rows x 2 columns]

# %% [markdown]
# # **Latihan (9)**

# %% [markdown]
# Tampilkan data dengan dataframe, dan data yang ditampilkan adalah data pada baris dengan indeks 0 (nol) sampai dengan indeks 9 (sembilan)

# %%
#Latihan (9)
#Tampilkan data dengan dataframe, dan data yang ditampilkan adalah baris dengan indeks 0 (nol) sampai dengan indeks 9 (sembilan)

df.loc[0:9]
# Out:
#   Gender    Age Education Level Institution Type IT Student Location  \
# 0    Boy  21-25      University   Non Government         No      Yes
# 1   Girl  21-25      University   Non Government         No      Yes
# 2   Girl  16-20         College       Government         No      Yes
# 3   Girl  11-15          School   Non Government         No      Yes
# 4   Girl  16-20          School   Non Government         No      Yes
# 5    Boy  11-15          School   Non Government         No      Yes
# 6    Boy  11-15          School   Non Government         No      Yes
# 7    Boy  11-15          School   Non Government         No      Yes
# 8    Boy  16-20         College       Government         No      Yes
# 9    Boy  11-15          School   Non Government         No      Yes
#
#   Load-shedding Financial Condition Internet Type Network Type Class Duration  \
# 0           Low                 Mid          Wifi           4G            3-6
# ...

# %% [markdown]
# # **Latihan (10)**

# %%
#Latihan (10)
#Tampilkan data hanya kolom "age" dan kolom "gender", pada baris dengan indeks 11 (nol) sampai dengan indeks 15 (sembilan)

df.loc[11:15, ['Age', 'Gender']]
# Out:
#       Age Gender
# 11  16-20   Girl
# 12  11-15    Boy
# 13  16-20   Girl
# 14  11-15   Girl
# 15  11-15    Boy

# %% [markdown]
# # **Latihan (11)**

# %%
#Latihan (11)
#Tampilkan data pada 8 (delapan) baris pertama dari dataset, dengan dataframe

df.head(8)
# Out:
#   Gender    Age Education Level Institution Type IT Student Location  \
# 0    Boy  21-25      University   Non Government         No      Yes
# 1   Girl  21-25      University   Non Government         No      Yes
# 2   Girl  16-20         College       Government         No      Yes
# 3   Girl  11-15          School   Non Government         No      Yes
# 4   Girl  16-20          School   Non Government         No      Yes
# 5    Boy  11-15          School   Non Government         No      Yes
# 6    Boy  11-15          School   Non Government         No      Yes
# 7    Boy  11-15          School   Non Government         No      Yes
#
#   Load-shedding Financial Condition Internet Type Network Type Class Duration  \
# 0           Low                 Mid          Wifi           4G            3-6
# 1          High                 Mid   Mobile Data           4G            1-3
# 2           Low                 Mid          Wifi           4G            1-3
# ...

# %% [markdown]
# # **Latihan (12)**

# %%
#Latihan (12)
#Tampilkan data pada 3 (tiga) baris terakhir dari dataset, dengan dataframe

df.tail(3)
# Out:
#      Gender    Age Education Level Institution Type IT Student Location  \
# 1202    Boy  11-15          School   Non Government         No      Yes
# 1203   Girl  16-20         College   Non Government         No       No
# 1204   Girl  11-15          School   Non Government         No      Yes
#
#      Load-shedding Financial Condition Internet Type Network Type  \
# 1202           Low                 Mid   Mobile Data           3G
# 1203           Low                 Mid          Wifi           4G
# 1204           Low                Poor   Mobile Data           3G
#
#      Class Duration Self Lms  Device Adaptivity Level
# 1202            1-3       No  Mobile         Moderate
# 1203            1-3       No  Mobile              Low
# 1204            1-3       No  Mobile         Moderate

# %% [markdown]
# # **Deskripsi Statistik Data**

# %% [markdown]
# DataFrame method describe() menampilkan statistik dasar setiap kolom data yang bertipe numerik, mencakup banyaknya data (count), rerata aritmetik (mean), simpangan baku (std), nilai terkecil (min), kuartil pertama (25%), kuartil kedua/median (50%), kuartil ketiga (75%), dan nilai terbesar (max).

# %% [markdown]
# # **Latihan (13)**

# %%
#Latihan (13)
#Hitung korelasi dataset

df.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
